# %%
import numpy as np

rng = np.random.default_rng(42)

# Datos de calificaciones de los estudiantes
matematicas = rng.integers(50, 100, 20)
ciencias = rng.integers(40, 95, 20)
literatura = rng.integers(60, 100, 20)

# Datos de errores para el gráfico de barras de error
errores_matematicas = rng.uniform(2, 5, 2)
errores_matematicas = [min(errores_matematicas), max(errores_matematicas)]

errores_ciencias = rng.uniform(1, 4, 2)
errores_ciencias = [min(errores_ciencias), max(errores_ciencias)]

errores_literatura = rng.uniform(3, 6, 2)
errores_literatura = [min(errores_literatura), max(errores_literatura)]

# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(42)

# Datos de calificaciones de los estudiantes
matematicas = rng.integers(50, 100, 20)
ciencias = rng.integers(40, 95, 20)

#Crea un gráfico de dispersión que muestre la relación entre las calificaciones de Matemáticas y Ciencias de los estudiantes.
#Utiliza los datos de las calificaciones de Matemáticas en el eje x y las calificaciones de Ciencias en el eje y.
#Personaliza el gráfico con etiquetas de los ejes y un título descriptivo.
#El gráfico debe salir igual al siguiente:
plt.scatter(matematicas , ciencias , color ="red")
plt.title('calificaciones Matematicas y Ciencias  ')
plt.xlabel('matematicas')
plt.ylabel('ciencias')

plt.show()

# %%
"""Gráfico de barras de error:
Crea un gráfico de barras de error que muestre las calificaciones promedio y sus errores correspondientes en las tres materias.
Utiliza los datos de calificaciones y errores para cada materia.
Personaliza el gráfico con etiquetas de los ejes, un título descriptivo y una leyenda que indique las materias.
El gráfico debe salir igual al siguiente:"""

import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(42)

# Datos de calificaciones de los estudiantes
# y promedio 
matematicas = rng.integers(50, 100, 20)
promedio_matematicas = np.mean(matematicas)
ciencias = rng.integers(40, 95, 20)
promedio_ciencias= np.mean(ciencias)
literatura = rng.integers(60, 100, 20)
promedio_literatura = np.mean(literatura)
#print(promedio_matematicas)
#print(promedio_ciencias)
#print(promedio_literatura)

promedio_calificasciones  = [promedio_matematicas,promedio_ciencias,promedio_literatura]
#pomedio de errores import numpy as np

rng = np.random.default_rng(42)

# Datos de errores para el gráfico de barras de error
errores_matematicas = rng.uniform(2, 5, 2)
errores_ciencias = rng.uniform(1, 4, 2)
errores_literatura = rng.uniform(3, 6, 2)

# Calcula el promedio de los errores
promedio_errores_matematicas = np.mean(errores_matematicas)
promedio_errores_ciencias = np.mean(errores_ciencias)
promedio_errores_literatura = np.mean(errores_literatura)
# Imprime los resultados
#print("Promedio de errores en Matemáticas:", promedio_errores_matematicas)
#print("Promedio de errores en Ciencias:", promedio_errores_ciencias)
#print("Promedio de errores en Literatura:", promedio_errores_literatura)

# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(42)

Materias = ['Matemasticas','Ciencias','Literatura']
promedio_calificasciones  = [promedio_matematicas,promedio_ciencias,promedio_literatura]
errores = [promedio_errores_matematicas,promedio_errores_ciencias,promedio_errores_literatura]

plt.errorbar(Materias,promedio_calificasciones, yerr=errores , fmt = 'o',capsize=5 , color = "red"  )
plt.title("Calificaciones con barras de error ")
plt.xlabel('Materias')
plt.ylabel("Calificaciones promedio")

plt.legend()
plt.legend(['promedio'])
plt.show
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
"""Histograma:
Crea un histograma que muestre la distribución de las calificaciones de Matemáticas.
Personaliza el histograma con etiquetas de los ejes y un título descriptivo.
El gráfico debe salir igual al siguiente:"""
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(42)

# Datos de calificaciones de los estudiantes
matematicas = rng.integers(50, 100, 20)
plt.hist(matematicas,color='black' , edgecolor = "red")
plt.title('Distribucion de las calificaciones de Mantemáticas')
plt.xlabel('Calificaciones de Matemáticas ')
plt.ylabel('Frecuencia')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
